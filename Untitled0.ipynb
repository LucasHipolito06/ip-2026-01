# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasHipolito06/ip-2026-01/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Resolução da lista 1
# Lucas Hipólito Batista de Carvalho
#
# matrícula: 202604076

# %% [markdown]
# QUESTÃO 1

# %%
Algoritmo "MédiaAluno"

 var
    nota1, nota2, nota3, media: real

 inicio
    escreva("Digite a primeira nota:")
    leia(nota1)
    escreva("Digite a segunda nota:")
    leia(nota2)
    escreva("Digite s terceira nota:")
    leia(nota3)

    media <- (nota1 + nota2 + nota3) / 3

    escreval("Média:", media)

    se (media >= 6) entao
      escreval("Aluno aprovado")
    senao
      escreva("Aluno reprovado")
    fimse

fimalgoritmo

# %% [markdown]
# Questao 2

# %%
Algoritmo "ArrecadaçãoJogos"

 var
  publico_total, publico_popular, publico_geral, publico_arqui, publico_cadeira, renda_total, renda_popular, renda_geral, renda_arqui, renda_ cadeira: inteiro

inicio
 escreva("Qual o público total do jogo?")
 leia(publico_total)
 escreva("Qual a porcentagem do público na categoria popular?")
 leia(publico_popular)
 escreva("Qual a porcentagem do público na categoria geral?")
 leia(publico_geral)
 escreva("Qual a porcentagem do público na categoria arquibancada?")
 leia(publico_arqui)
 escreva("Qual a porcentagem do público na categoria cadeira?")
 leia(publico_cadeira)

renda_popular <- publico_popular * publico_total * 1 / 100
renda_geral <- publico_geral * publico_total * 5 / 100
renda_arqui <- publico_arqui * publico_total * 10 / 100
renda_cadeira <- publico_cadeira * publico_total * 20 / 100

renda_total <- renda_popular + renda_geral + renda_arqui + renda_cadeira

escreval("A renda total do jogo é:", renda_total)

fimalgoritmo

# %% [markdown]
# Questao 3

# %%
Algoritmo "Composiçãointeira"

 var
  numero1, numero2, numero3, numero_final1: inteiro
  numero_final2: real

inicio
  escreva("Digite o primeiro número:")
  leia(numero1)
  escreva("Digite o segundo número:")
  leia(numero2)
  escreva("Digite o terceiro número:")
  leia(numero3)

  se (numero1 <= 0) ou (numero1 > 9) ou (numero2 > 9) ou (numero3 > 9) entao
   escreval("DIGITO INVÁLIDO")
  senao
   numero_final1 <- numero1 * 100 + numero2 * 10 + numero3
   numero_final2 <- (numero1 * 100 + numero2 * 10 + numero3) ^ 2

  escreva(numero_final1, ", ", numero_final2)
fimse

fimalgortimo

# %% [markdown]
# Questão 4

# %%
Algoritmo "ConsumoEnergia"

  var
   salario_minimo, custo_por_kw, kw_gasto, custo_consumo, custo_desconto: real

  inicio
  escreva("Qual o salário mínimo?")
  leia(salario_minimo)
  escreva("Quantos kw foram gastos neste mês?")
  leia(kw_gasto)

  custo_por_kw <- salario_minimo * 0.007
  custo_consumo <- custo_por_kw * kw_gasto
  custo_desconto <- custo_consumo * 0.9

  escreval("Custo por kw: R$", custo_por_kw)
  escreval("Custo do consumo:R$", custo_consumo)
  escrveal("Custo com desconto:R$", custo_desconto)

fimalgoritmo

# %% [markdown]
# Questão 5

# %%
Algoritmo "ContaAgua"

 var
  conta: inteiro
  valor, consumo: real
  tipo_cons: caractere

inicio
 escreva("Qual o número da conta?")
 leia(conta)
 escreva("Quanto foi consumido?")
 leia(consumo)
 escreva("Qual o tipo de consumidor?")
 leia(tipo_cons)

 se tipo_cons = "R" entao
  valor <- 5 + consumo * 0.05
   senao
    se tipo_cons = "C" entao
    valor <- 500 + consumo * 0.25
     senao
      se tipo_cons = "I" entao
       valor <- 800 + consumo * 0.04
       fimse
    fimse
  fimse
 escreval("Conta:", conta|)
 escreval("Valor da conta:", valor)

fimalgoritmo

# %% [markdown]
# Questão 6

# %%
Algoritmo "ConversaoCelsius"

 var
   celsius1, celsius2, celsius3, celsius4, temperatura1, temperatura2, temperatura3, temperatura4: real

 inicio
   escreva("Qual a 1° temperatura?")
   leia(temperatura1)
   escreva("Qual a 2° temperatura?")
   leia(temperatura2)
   escreva("Qual a 3° temperatura?")
   leia(temperatura3)
   escreva("Qual a 4° temperatura?")
   leia(temperatura4)

   celsius1 <- 5*(temperatura1 - 32) / 9
   celsius2 <- 5*(temperatura2 - 32) / 9
   celsius3 <- 5*(temperatura3 - 32) / 9
   celsius4 <- 5*(temperatura4 - 32) / 9

   escreval(temperatura1, " Fahrenheit equivale a", celsius1, " celsius")
   escreval(temperatura2, " Fahrenheit equivale a", celsius2, " celsius")
   escreval(temperatura3, " Fahrenheit equivale a", celsius3, " celsius")
   escreval(temperatura4, " Fahrenheit equivale a", celsius4, " celsius")

fimalgoritmo

# %% [markdown]
# Questão 7

# %%
Algoritmo "ConversaodeUnidades"

 var
    temp_fahrenheit, celsius, chuva_polegadas, chuva_mm: real

 inicio
 escreva("Qual a temperatura em Fahrenheit?")
 leia(temp_fahrenheit)
 escreva("Quantas polegadas choveram?")
 leia(chuva_polegadas)

 celsius <- (5 * temp_fahrenheit - 160) / 9
 chuva_mm <- chuva_polegadas * 25,4

 escreval("O valor em celsius é:", celsius)
 escreval("A quantidade de chuva E=", chuva_mm, "mm")

fimalgoritmo

# %% [markdown]
# Questão 8

# %%
Algoritmo "LataCerveja"

 var
  raio_lata, altura_lata, area_total, area_circulo, area_lateral, custo: real

inicio
 escreva("Qual o raio da lata em metros?")
 leia(raio_lata)
 escreva("Qual a altura da lata em metros?")
 leia(altura_lata)

 area_circulo <- 3.14 * raio_lata ^ 2
 area_lateral <- 2 * 3.14 * raio_lata * altura_lata
 area_total <- 2 * area_circulo + area_lateral
 custo <- area_total * 100

 escreval("O valor do custo é:", custo)

fimalgoritmo

# %% [markdown]
# Questão 9

# %%
Algoritmo "CalculoDelta"

  var
   coeficiente_A, coeficiente_B, coeficiente_C: inteiro
   delta: real

  inicio
  escreva("Qual o coeficiente A?")
  leia(coeficiente_A)
  escreva("Qual o coeficiente B?")
  leia(coeficiente_B)
  escreva("Qual o coeficiente C?")
  leia(coeficiente_C)

  delta <- coeficiente_B ^ 2 - 4 * coeficiente_A * coeficiente_C

  escreval("O valor do delta é:", delta)

fimalgoritmo

# %% [markdown]
# Questão 10

# %%
Algoritmo "DeterminanteMatriz"

var
 coefic_a, coefic_b, coefic_c, coefic_d, det: real

inicio
 escreva("Qual o coeficiente A?")
 leia(coefic_a)
 escreva("Qual o coeficiente B?")
 leia(coefic_b)
 escreva("Qual o coeficiente C?")
 leia(coefic_c)
 escreva("Qual o coeficiente D?")
 leia(coefic_d)

det <- coefic_a * coefic_d - coefic_b * coefic_c

escreval("O valor do determinante é:", det)

fimalgoritmo

# %% [markdown]
# Questão 11

# %%
Algoritmo "Numerodivisivel"

 var
  numero: inteiro

 inicio
  escreva("Digite um número inteiro:")
  leia(numero)

  se (numero mod 3 = 0) e (numero mod 5 = 0) entao
   escreva("O número é divisível")
  senao
   escreva("O número não é divisível")
  fimse

fimalgoritmo

# %% [markdown]
# Questão 12

# %%
Algoritmo "Charrete"

 var
  horas, blocos, resto: inteiro
  valor: real

inicio
 escreva("Quantas horas a charrete foi alugada?")
 leia(horas)

 blocos <- horas div 3
 resto <- horas mod 3

 valor <- blocos * 10 + resto * 5

 escreval("O valor total a pagar é:", valor)

fimalgoritmo

# %% [markdown]
# Questão 13

# %%
 Programa "Conversaoemnota"

  var
   nota: real

  inicio
  escreva("Qual a nota do aluno?")
  leia(nota)

  se nota >= 9 entao
   escreva("NOTA =", nota, " Conceito A")
    senao
     se nota >= 7.5 entao
      escreva("NOTA =", nota, " Conceito B")
       senao
        se nota >= 6 entao
         escreva("NOTA =", nota, " Conceito C")
          senao
           se nota < 6 entao
            escreva("NOTA =", nota, " Conceito D")
           fimse

fimalgortimo

# %% [markdown]
# Questão 14

# %%
Algoritmo "PiramidadeHexagonal"

 var
  altura_pi, aresta_pi, areabase_pi, volume_pi: real

 inicio
 escreva("Qual a altura da pirâmide em metros?")
 leia(altura_pi)
 escreva("Qual a aresta da piramide em metros?")
 leia(aresta_pi)

 areabase_pi <- 3 * aresta_pi ^2 * 1.73 / 2
 volume_pi <- areabase_pi * altura_pi / 3
 #adotei raiz de 3 como 1.73

 escreval("O volume da pirâmide é:", volume_pi)

fimalgoritmo

# %% [markdown]
# Questão 15

# %%
Algoritmo "QuadradoPares"

 var
  numero, i: inteiro

inicio
 escreva("Digite um número inteiro:")
 leia(numero)

 para i de 2 ate numero passo 2 faca
  escreva(i, "^2 =", i*i)
fimpara

fimalgoritmo

# %% [markdown]
# Questão 16

# %%
 Algoritmo "ReajusteSalarial"

  var
   salario: real

  inicio
  escreva("Qual o salário inicial?")
  leia(salario)

  se salario <= 300 entao
   escreva("O novo salário é:", salario * 1.5)
  senao
   escreva("O novo salário é:", salario * 1.3)

  fimse

fimalgoritmo

# %% [markdown]
# Questão 17

# %%
Algoritmo "SeriePar"

var
 x, y, i: inteiro

inicio
 escreva("Qual o valor de x?")
 leia(x)
 escreva("Qual o valor de y?")
 leia(y)

 se (x mod 2 = 0) entao

  para i de 0 atw y-1 faca
   escreva(x + i*2, "")
  fimpara

  escreval("")

  senao
   escreval("O primeiro numero não é par")
  fimse

fimalgoritmo

# %% [markdown]
# Questão 18

# %%
Algoritmo "SomaPA"

 var
  valor_inicio, razao, n_termos, i: inteiro
  termo, soma: inteiro

inicio
 escreva("Qual o valor inicial da PA?")
 leia(valor_inicio)
 escreva("Qual a razão da PA?")
 leia(razao)
 escreva("Qual a quantidade de termos da PA?")
 leia(n_termos)

 soma <- 0
 termo <- valor_inicial
 i <- 1

 enquanto i <= faca
  soma <- soma + termo
  termo <- termo + razao
  i <- i + 1
  fimenquanto

  escreval(soma)

fimalgoritmo
#esse bugou no visualG

# %% [markdown]
# Questão 19

# %%
Algoritmo "Somatorio"

var
 numero, somatorio: inteiro
 soma: real

inicio
 escreva("Digite um número inteiro:")
 leia(numero)

 se (numero <= 1) entao
  escreval("Numero invalido")
 senao

  soma <- 0

  para somatorio de 1 ate n faca
   soma <- soma + (1/somatorio)
  fimpara

  escreval(soma)

 fimse

fimalgoritmo #penei

# %% [markdown]
# Questão 20

# %%
Algoritmo "TempoemSegundo"

 var
  hora, minuto, segundo, hora_segundo, minuto_segundo, segundo_segundo, soma_total: inteiro

 inicio
  escreva("Em que hora estou?")
  leia(hora)
  escreva("Em que minuto estou?")
  leia(minuto)
  escreva("Em que segundo estou?")
  leia(segundo)

  hora_segundo <- (hora * 3600)
  minuto_segundo <- (minuto * 60)
  segundo_segundo <- (segundo * 1)
  soma_total <- (hora_segundo + minuto_segundo + segundo_segundo)

  escreval("O tempo em segundos é", soma_total)

fimalgoritmo
